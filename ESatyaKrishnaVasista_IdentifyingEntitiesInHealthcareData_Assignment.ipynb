# %% [markdown]
# # Syantactic Processing - Identifying Entities in Healthcare Data Assignment

# %% [markdown]
# Project URL: https://github.com/Vasista-Eranki/SyntacticProcessingAssignment/

# %% [markdown]
# ### Imports and Prepare the Model

# %%
#!pip install spacy
#!pip install sklearn-crfsuite

# %%
import spacy
import sklearn_crfsuite
from sklearn_crfsuite import metrics

model = spacy.load("en_core_web_sm")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read the input file contents

# %%
base_dir = './'
with open(base_dir+'train_sent', 'r') as train_sentence_file:
  input_train_sent = train_sentence_file.readlines()

with open(base_dir+'train_label', 'r') as train_label_file:
  input_train_labels = train_label_file.readlines()

with open(base_dir+'test_sent', 'r') as test_sentence_file:
  input_test_sent = test_sentence_file.readlines()

with open(base_dir+'test_label', 'r') as test_label_file:
  input_test_labels = test_label_file.readlines()

# %% [markdown]
# **The Lines in each file have \n as a trailing character. This needs to be trimmed down before creating the sentences**

# %%
def get_sentences(data):
    "Returns a list of sentences by joining the input data wherever an empty string value is encountered..."
    return_data = []
    current_line = ''
    for w in data:
        word = w.strip()
        if len(word) == 0 :
            return_data.append(current_line)
            current_line = ""
        else:
            if len(current_line) == 0:
                current_line = word
            else:
                current_line += ' '+ word
    return return_data

# %%
train_sentences = get_sentences(input_train_sent)
train_labels = get_sentences(input_train_labels)
test_sentences = get_sentences(input_test_sent)
test_labels = get_sentences(input_test_labels)

# %% [markdown]
# #### Number of Sentences in Train and Test dataset

# %%
print("Total Sentences in the training Corpus: ", len(train_sentences))
print("Total Sentences in the testing Corpus: ", len(test_sentences))
# Out:
# Total Sentences in the training Corpus:  2599
# Total Sentences in the testing Corpus:  1056

# %% [markdown]
# #### Number of lines of Labels in the Train and Test dataset

# %%
print("Total Labels in the training Corpus: ", len(train_labels))
print("Total Labels in the testing Corpus: ", len(test_labels))
# Out:
# Total Labels in the training Corpus:  2599
# Total Labels in the testing Corpus:  1056

# %% [markdown]
# ### Task-01: Print 5 sentences

# %% [markdown]
# #### Training sentences

# %%
for i in range(0,5):
    print("Sentence: ", train_sentences[i])
    print("Labels: ", train_labels[i], end="\n\n")
# Out:
# Sentence:  All live births > or = 23 weeks at the University of Vermont in 1995 ( n = 2395 ) were retrospectively analyzed for delivery route , indication for cesarean , gestational age , parity , and practice group ( to reflect risk status )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  Abnormal presentation was the most common indication ( 25.6 % , 88 of 344 )
# Labels:  O O O O O O O O O O O O O O O
#
# Sentence:  The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  Arrest of dilation was the most common indication in both `` corrected '' subgroups ( 23.4 and 24.6 % , respectively )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O

# %% [markdown]
# #### Testing sentences

# %%
for i in range(0,5):
    print("Sentence: ", test_sentences[i])
    print("Labels: ", test_labels[i], end="\n\n")
# Out:
# Sentence:  Furthermore , when all deliveries were analyzed , regardless of risk status but limited to gestational age > or = 36 weeks , the rates did not change ( 12.6 % , 280 of 2214 ; primary 9.2 % , 183 of 1994 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration
# Labels:  O O O O O O O O O O O O O O O O O O O
#
# Sentence:  The daily high temperature ranged from 71 to 104 degrees F and AFI values ranged from 1.7 to 24.7 cm during the study period
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  There was a significant correlation between the 2- , 3- , and 4-day mean temperature and AFI , with the 4-day mean being the most significant ( r = 0.31 , p & # 60 ; 0.001 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
# Sentence:  Fluctuations in ambient temperature are inversely correlated to changes in AFI
# Labels:  O O O O O O O O O O O

# %% [markdown]
# ### Task-02: Extract the POS - Frequency of NOUN OR PROPN in train & test corpus

# %%
train_data = pd.DataFrame(columns=['sent', 'Text', 'LEMMA', 'POS', 'DEP'])
test_data = pd.DataFrame(columns=['sent', 'Text', 'LEMMA', 'POS', 'DEP'])

# %%
for index, each_sent in enumerate(train_sentences):
    sent = model(each_sent)
    for token in sent:
        train_data.loc[len(train_data)] = {'sent': index, 'Text': token.text, 'LEMMA': token.lemma_, 'POS' : token.pos_, 'DEP': token.dep_}

# %%
for index, each_sent in enumerate(test_sentences):
    sent = model(each_sent)
    for token in sent:
        test_data.loc[len(test_data)] = {'sent': index, 'Text': token.text, 'LEMMA': token.lemma_, 'POS' : token.pos_, 'DEP': token.dep_}

# %%
nouns_in_train_data = train_data[(train_data.POS == 'NOUN') | (train_data.POS == 'PROPN')].loc[:, ['Text', 'POS']]
nouns_in_test_data = test_data[(test_data.POS == 'NOUN') | (test_data.POS == 'PROPN')].loc[:, ['Text', 'POS']]

final_nouns_in_data= pd.concat([nouns_in_train_data, nouns_in_test_data])

# %%
grouped_final_nouns_in_data = final_nouns_in_data.groupby(by='Text').agg('count').sort_values(by='POS', ascending=False).reset_index()

# %% [markdown]
# **Top 25 Most frequent words in the corpus (training+testing)**

# %%
grouped_final_nouns_in_data.head(25)
# Out:
#             Text  POS
# 0       patients  492
# 1      treatment  281
# 2              %  247
# 3         cancer  200
# 4        therapy  175
# 5          study  154
# 6        disease  142
# 7           cell  140
# 8           lung  116
# 9          group   94
# 10  chemotherapy   88
# 11          gene   87
# 12       effects   85
# 13       results   79
# 14         women   77
# 15           use   74
# 16        TO_SEE   74
# 17         cases   71
# 18       surgery   71
# 19          risk   71
# 20      analysis   70
# 21          rate   67
# 22      response   66
# 23      survival   65
# 24      children   64

# %% [markdown]
# ### Task-03: Define the CRF Features

# %% [markdown]
# #### Functions to Process the Sentences

# %%
def features_for_word(words, position, pos_tags):
    word = words[position]
    features = [
        'word.lower=' + word.lower(), # serves as word id
        'word[-3:]=' + word[-3:],     # last three characters
        'word[-2:]=' + word[-2:],     # last two characters
        'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
        'word.isdigit=%s' % word.isdigit(),  # is the word a number
        'word.startsWithCapital=%s' % word[0].isupper(), # is the word starting with a capital letter
        'word.pos=' + pos_tags[position]
    ]
    if position > 0:
        prev_word = words[position-1]
        previous_word_features = [
        'prev_word.lower=' + prev_word.lower(),
        'prev_word.isupper=%s' % prev_word.isupper(),
        'prev_word.isdigit=%s' % prev_word.isdigit(),
        'prev_word.startsWithCapital=%s' % prev_word[0].isupper(),
        'prev_word.pos=' + pos_tags[position-1]]
        features.extend(previous_word_features)
    else:
        features.append('BEG')

    if (position == len(pos_tags)-1):
        features.append('END')

    return features

# %% [markdown]
# #### Functions to process the Labels

# %%
def labels_for_sentence(labels):
  return labels.split()

# %% [markdown]
# ### Task-04: Compute the Features of a Sentence

# %%
def features_for_sentence(sentence):
    spacy_sentence = model(sentence)

    pos_tags = []
    #pos_tags = [word.pos_ for word in spacy_sentence]
    for token in spacy_sentence:
        pos_tags.append(token.pos_)

    words = sentence.split()

    return [features_for_word(words, i, pos_tags) for i in range(0, len(words))]

# %%
features_for_sentence(train_sentences[0])[-1]
# Out:
# ['word.lower=)',
#  'word[-3:]=)',
#  'word[-2:]=)',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'word.startsWithCapital=False',
#  'word.pos=PUNCT',
#  'prev_word.lower=status',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_word.startsWithCapital=False',
#  'prev_word.pos=NOUN',
#  'END']

# %% [markdown]
# ### Task-05: Extract Features' Values for the Sentence

# %%
X_train = [features_for_sentence(sentence) for sentence in train_sentences]
Y_train = [labels_for_sentence(labels) for labels in train_labels]

# %%
X_test = [features_for_sentence(sentence) for sentence in test_sentences]
Y_test = [labels_for_sentence(labels) for labels in test_labels]

# %%
print(X_train[0][-1])
# Out:
# ['word.lower=)', 'word[-3:]=)', 'word[-2:]=)', 'word.isupper=False', 'word.isdigit=False', 'word.startsWithCapital=False', 'word.pos=PUNCT', 'prev_word.lower=status', 'prev_word.isupper=False', 'prev_word.isdigit=False', 'prev_word.startsWithCapital=False', 'prev_word.pos=NOUN', 'END']

# %%
print(Y_train[35])
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'D', 'D', 'D']

# %%
print(Y_test[29])
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D', 'D', 'O', 'O', 'O', 'O', 'D', 'D', 'O', 'O', 'O', 'O', 'O', 'D', 'D']

# %% [markdown]
# ### Task-06: CRF model for a custom NER application

# %%
import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %%
crf = sklearn_crfsuite.CRF(max_iterations=100)

try:
    crf.fit(X_train, Y_train)
except AttributeError as e:
    print('EXCEPTION:', e)
    pass

# %% [markdown]
# ### Evaluation of the Model

# %%
print("Classes identified in the custom CRF model:", crf.classes_)
# Out:
# Classes identified in the custom CRF model: ['O', 'D', 'T']

# %% [markdown]
# **Print Transition Details**

# %%
crf.transition_features_
# Out:
# {('O', 'O'): 0.899472,
#  ('O', 'D'): 0.588422,
#  ('O', 'T'): -1.918435,
#  ('D', 'O'): -0.8025,
#  ('D', 'D'): 4.574284,
#  ('D', 'T'): -1.857337,
#  ('T', 'O'): 0.633899,
#  ('T', 'T'): 3.719617}

# %%
crf.state_features_
# Out:
# {('word.lower=all', 'O'): 0.234134,
#  ('word[-3:]=All', 'O'): 0.024385,
#  ('word[-2:]=ll', 'O'): -0.019916,
#  ('word[-2:]=ll', 'D'): 0.245115,
#  ('word[-2:]=ll', 'T'): -0.225199,
#  ('word.isupper=False', 'O'): 1.0545,
#  ('word.isupper=False', 'D'): -0.490619,
#  ('word.isupper=False', 'T'): -0.563881,
#  ('word.isdigit=False', 'O'): 0.085916,
#  ('word.isdigit=False', 'D'): 0.057947,
#  ('word.isdigit=False', 'T'): -0.143863,
#  ('word.startsWithCapital=True', 'O'): 1.009713,
#  ('word.startsWithCapital=True', 'D'): -0.459867,
#  ('word.startsWithCapital=True', 'T'): -0.549846,
#  ('word.pos=DET', 'O'): 0.382093,
#  ('word.pos=DET', 'D'): -0.145612,
#  ('word.pos=DET', 'T'): -0.236481,
#  ('BEG', 'O'): 0.733014,
#  ('BEG', 'D'): 0.052865,
#  ('BEG', 'T'): -0.785879,
#  ('word.lower=live', 'O'): 0.005976,
#  ('word[-3:]=ive', 'O'): -0.043213,
#  ('word[-3:]=ive', 'D'): 0.107902,
#  ('word[-3:]=ive', 'T'): -0.064689,
#  ('word[-2:]=ve', 'O'): 0.052991,
#  ('word[-2:]=ve', 'D'): -0.167837,
#  ('word[-2:]=ve', 'T'): 0.114846,
#  ('word.startsWithCapital=False', 'O'): 0.454172,
#  ('word.startsWithCapital=False', 'D'): -0.161985,
#  ('word.startsWithCapital=False', 'T'): -0.292187,
#  ('word.pos=ADJ', 'O'): -0.087178,
#  ('word.pos=ADJ', 'D'): 0.156297,
#  ('word.pos=ADJ', 'T'): -0.069119,
#  ('prev_word.lower=all', 'O'): 0.216327,
#  ('prev_word.isupper=False', 'O'): 0.133376,
#  ('prev_word.isupper=False', 'D'): -0.193573,
#  ('prev_word.isupper=False', 'T'): 0.060197,
#  ('prev_word.isdigit=False', 'O'): 0.41681,
#  ('prev_word.isdigit=False', 'D'): -0.6381,
#  ('prev_word.isdigit=False', 'T'): 0.221291,
#  ('prev_word.startsWithCapital=True', 'O'): 0.253218,
#  ('prev_word.startsWithCapital=True', 'D'): -0.283598,
#  ('prev_word.startsWithCapital=True', 'T'): 0.03038,
#  ('prev_word.pos=DET', 'O'): 0.081856,
#  ('prev_word.pos=DET', 'D'): 0.045304,
#  ('prev_word.pos=DET', 'T'): -0.12716,
#  ('word.lower=births', 'O'): 0.005853,
#  ('word[-3:]=ths', 'O'): 0.221418,
#  ('word[-2:]=hs', 'O'): 0.221418,
#  ('word.pos=NOUN', 'O'): -0.63562,
#  ('word.pos=NOUN', 'D'): 0.372748,
#  ('word.pos=NOUN', 'T'): 0.262872,
#  ('prev_word.lower=live', 'O'): 0.006547,
#  ('prev_word.startsWithCapital=False', 'O'): 0.477653,
#  ('prev_word.startsWithCapital=False', 'D'): -0.391119,
#  ('prev_word.startsWithCapital=False', 'T'): -0.086535,
#  ('prev_word.pos=ADJ', 'O'): -0.167297,
#  ('prev_word.pos=ADJ', 'D'): 0.142655,
#  ('prev_word.pos=ADJ', 'T'): 0.024642,
#  ('word.lower=>', 'O'): 0.405267,
#  ('word[-3:]=>', 'O'): 0.405267,
#  ('word[-2:]=>', 'O'): 0.405267,
#  ('word.pos=X', 'O'): 0.430971,
#  ('word.pos=X', 'D'): -0.320638,
#  ('word.pos=X', 'T'): -0.110333,
#  ('prev_word.lower=births', 'O'): 0.001294,
#  ('prev_word.pos=NOUN', 'O'): 0.346967,
#  ('prev_word.pos=NOUN', 'D'): -0.292107,
#  ('prev_word.pos=NOUN', 'T'): -0.05486,
#  ('word.lower=or', 'O'): 0.549754,
#  ('word.lower=or', 'D'): -0.246853,
#  ('word.lower=or', 'T'): -0.302901,
#  ('word[-3:]=or', 'O'): 0.507773,
#  ('word[-3:]=or', 'D'): -0.230763,
#  ('word[-3:]=or', 'T'): -0.27701,
#  ('word[-2:]=or', 'O'): 0.459484,
#  ('word[-2:]=or', 'D'): -0.599124,
#  ('word[-2:]=or', 'T'): 0.13964,
#  ('word.pos=CCONJ', 'O'): -0.230156,
#  ('word.pos=CCONJ', 'D'): 0.100472,
#  ('word.pos=CCONJ', 'T'): 0.129684,
#  ('prev_word.lower=>', 'O'): -0.891096,
#  ('prev_word.lower=>', 'D'): 0.779779,
#  ('prev_word.lower=>', 'T'): 0.111317,
#  ('prev_word.pos=X', 'O'): -0.337452,
#  ('prev_word.pos=X', 'D'): 0.31223,
#  ('prev_word.pos=X', 'T'): 0.025222,
#  ('word.lower==', 'O'): 0.299217,
#  ('word[-3:]==', 'O'): 0.299217,
#  ('word[-2:]==', 'O'): 0.299217,
#  ('word.pos=PRON', 'O'): 0.177191,
#  ('word.pos=PRON', 'D'): -0.248807,
#  ('word.pos=PRON', 'T'): 0.071616,
#  ('prev_word.lower=or', 'O'): -0.640791,
#  ('prev_word.lower=or', 'D'): 0.419636,
#  ('prev_word.lower=or', 'T'): 0.221156,
#  ('prev_word.pos=CCONJ', 'O'): 0.152342,
#  ('prev_word.pos=CCONJ', 'D'): 0.00677,
#  ('prev_word.pos=CCONJ', 'T'): -0.159112,
#  ('word.lower=23', 'O'): 0.006215,
#  ('word[-3:]=23', 'O'): 0.006215,
#  ('word[-2:]=23', 'O'): 0.013004,
#  ('word.isdigit=True', 'O'): 1.377969,
#  ('word.isdigit=True', 'D'): -0.679799,
#  ('word.isdigit=True', 'T'): -0.69817,
#  ('word.pos=NUM', 'O'): 0.322931,
#  ('word.pos=NUM', 'D'): -0.134337,
#  ('word.pos=NUM', 'T'): -0.188594,
#  ('prev_word.lower==', 'O'): 0.315549,
#  ('prev_word.pos=PRON', 'O'): -0.035335,
#  ('prev_word.pos=PRON', 'D'): 0.227926,
#  ('prev_word.pos=PRON', 'T'): -0.192591,
#  ('word.lower=weeks', 'O'): 0.175842,
#  ('word[-3:]=eks', 'O'): 0.175842,
#  ('word[-2:]=ks', 'O'): -0.128038,
#  ('word[-2:]=ks', 'D'): -0.205926,
#  ('word[-2:]=ks', 'T'): 0.333964,
#  ('prev_word.lower=23', 'O'): 0.009123,
#  ('prev_word.isdigit=True', 'O'): 0.314062,
#  ('prev_word.isdigit=True', 'D'): -0.036617,
#  ('prev_word.isdigit=True', 'T'): -0.277445,
#  ('prev_word.pos=NUM', 'O'): 0.233791,
#  ('prev_word.pos=NUM', 'D'): -0.338538,
#  ('prev_word.pos=NUM', 'T'): 0.104747,
#  ('word.lower=at', 'O'): 0.512972,
#  ('word[-3:]=at', 'O'): 0.467961,
#  ('word[-2:]=at', 'O'): 0.846725,
#  ('word[-2:]=at', 'D'): -0.254972,
#  ('word[-2:]=at', 'T'): -0.591753,
#  ('word.pos=ADP', 'O'): -0.03665,
#  ('word.pos=ADP', 'D'): 0.314544,
#  ('word.pos=ADP', 'T'): -0.277894,
#  ('prev_word.lower=weeks', 'O'): 0.088347,
#  ('word.lower=the', 'O'): 0.479262,
#  ('word.lower=the', 'D'): -0.185976,
#  ('word.lower=the', 'T'): -0.293286,
#  ('word[-3:]=the', 'O'): 0.138052,
#  ('word[-3:]=the', 'D'): 0.015999,
#  ('word[-3:]=the', 'T'): -0.154051,
#  ('word[-2:]=he', 'O'): 0.15564,
#  ('word[-2:]=he', 'D'): 0.071251,
#  ('word[-2:]=he', 'T'): -0.226891,
#  ('prev_word.lower=at', 'O'): 0.865008,
#  ('prev_word.pos=ADP', 'O'): -0.208884,
#  ('prev_word.pos=ADP', 'D'): -0.005707,
#  ('prev_word.pos=ADP', 'T'): 0.214591,
#  ('word.lower=university', 'O'): 0.033533,
#  ('word[-3:]=ity', 'O'): 0.469623,
#  ('word[-3:]=ity', 'D'): 0.573448,
#  ('word[-3:]=ity', 'T'): -1.043072,
#  ('word[-2:]=ty', 'O'): -0.121671,
#  ('word[-2:]=ty', 'D'): -0.204601,
#  ('word[-2:]=ty', 'T'): 0.326272,
#  ('word.pos=PROPN', 'O'): -1.038595,
#  ('word.pos=PROPN', 'D'): 0.550065,
#  ('word.pos=PROPN', 'T'): 0.48853,
#  ('prev_word.lower=the', 'O'): -0.119819,
#  ('prev_word.lower=the', 'D'): 0.038704,
#  ('prev_word.lower=the', 'T'): 0.081115,
#  ('word.lower=of', 'O'): 0.668274,
#  ('word.lower=of', 'D'): -0.299286,
#  ('word.lower=of', 'T'): -0.368988,
#  ('word[-3:]=of', 'O'): 0.656932,
#  ('word[-3:]=of', 'D'): -0.295158,
#  ('word[-3:]=of', 'T'): -0.361774,
#  ('word[-2:]=of', 'O'): 0.656932,
#  ('word[-2:]=of', 'D'): -0.295158,
#  ('word[-2:]=of', 'T'): -0.361774,
#  ('prev_word.lower=university', 'O'): 0.036138,
#  ('prev_word.pos=PROPN', 'O'): 0.603684,
#  ('prev_word.pos=PROPN', 'D'): -0.378049,
#  ('prev_word.pos=PROPN', 'T'): -0.225635,
#  ('word.lower=vermont', 'O'): 0.012489,
#  ('word[-3:]=ont', 'O'): 0.012489,
#  ('word[-2:]=nt', 'O'): 0.094634,
#  ('word[-2:]=nt', 'D'): -0.24808,
#  ('word[-2:]=nt', 'T'): 0.153445,
#  ('prev_word.lower=of', 'O'): -1.171895,
#  ('prev_word.lower=of', 'D'): 0.752974,
#  ('prev_word.lower=of', 'T'): 0.41892,
#  ('word.lower=in', 'O'): 1.582924,
#  ('word.lower=in', 'D'): -0.821539,
#  ('word.lower=in', 'T'): -0.761386,
#  ('word[-3:]=in', 'O'): 1.507356,
#  ('word[-3:]=in', 'D'): -0.784843,
#  ('word[-3:]=in', 'T'): -0.722513,
#  ('word[-2:]=in', 'O'): -0.712822,
#  ('word[-2:]=in', 'D'): -0.324198,
#  ('word[-2:]=in', 'T'): 1.03702,
#  ('prev_word.lower=vermont', 'O'): 0.000595,
#  ('word.lower=1995', 'O'): 0.06155,
#  ('word[-3:]=995', 'O'): 0.065189,
#  ('word[-2:]=95', 'O'): 0.095297,
#  ('prev_word.lower=in', 'O'): -0.002777,
#  ('prev_word.lower=in', 'D'): 0.762537,
#  ('prev_word.lower=in', 'T'): -0.75976,
#  ('word.lower=(', 'O'): 0.23837,
#  ('word.lower=(', 'D'): -0.154632,
#  ('word.lower=(', 'T'): -0.083739,
#  ('word[-3:]=(', 'O'): 0.23837,
#  ('word[-3:]=(', 'D'): -0.154632,
#  ('word[-3:]=(', 'T'): -0.083739,
#  ('word[-2:]=(', 'O'): 0.23837,
#  ('word[-2:]=(', 'D'): -0.154632,
#  ('word[-2:]=(', 'T'): -0.083739,
#  ('word.pos=PUNCT', 'O'): -0.623433,
#  ('word.pos=PUNCT', 'D'): 0.150426,
#  ('word.pos=PUNCT', 'T'): 0.473007,
#  ('prev_word.lower=1995', 'O'): -0.056396,
#  ('prev_word.lower=1995', 'T'): 0.10147,
#  ('word.lower=n', 'O'): -0.152845,
#  ('word.lower=n', 'D'): 0.200091,
#  ('word[-3:]=n', 'O'): -0.152845,
#  ('word[-3:]=n', 'D'): 0.200091,
#  ('word[-2:]=n', 'O'): -0.152845,
#  ('word[-2:]=n', 'D'): 0.200091,
#  ('prev_word.lower=(', 'O'): 0.044889,
#  ('prev_word.lower=(', 'D'): -0.040048,
#  ('prev_word.lower=(', 'T'): -0.004841,
#  ('prev_word.pos=PUNCT', 'O'): 0.095321,
#  ('prev_word.pos=PUNCT', 'D'): 0.02324,
#  ('prev_word.pos=PUNCT', 'T'): -0.118561,
#  ('word.pos=SYM', 'O'): 0.364135,
#  ('word.pos=SYM', 'T'): 0.067868,
#  ('prev_word.lower=n', 'O'): -0.213919,
#  ('prev_word.lower=n', 'D'): 0.244807,
#  ('word.lower=2395', 'O'): 0.004558,
#  ('word[-3:]=395', 'O'): 0.004558,
#  ('prev_word.pos=SYM', 'O'): 0.142637,
#  ('prev_word.pos=SYM', 'D'): -0.289828,
#  ('prev_word.pos=SYM', 'T'): 0.147191,
#  ('word.lower=)', 'O'): -0.318127,
#  ('word.lower=)', 'D'): 0.143282,
#  ('word.lower=)', 'T'): 0.174845,
#  ('word[-3:]=)', 'O'): -0.318127,
#  ('word[-3:]=)', 'D'): 0.143282,
#  ('word[-3:]=)', 'T'): 0.174845,
#  ('word[-2:]=)', 'O'): -0.318127,
#  ('word[-2:]=)', 'D'): 0.143282,
#  ('word[-2:]=)', 'T'): 0.174845,
#  ('prev_word.lower=2395', 'O'): 0.011758,
#  ('word.lower=were', 'O'): 0.606811,
#  ('word[-3:]=ere', 'O'): 0.532267,
#  ('word[-3:]=ere', 'D'): -0.069206,
#  ('word[-2:]=re', 'O'): 0.490449,
#  ('word[-2:]=re', 'D'): 0.010252,
#  ('word[-2:]=re', 'T'): -0.5007,
#  ('word.pos=AUX', 'O'): 1.090068,
#  ('word.pos=AUX', 'D'): -0.637525,
#  ('word.pos=AUX', 'T'): -0.452543,
#  ('prev_word.lower=)', 'O'): 1.042251,
#  ('prev_word.lower=)', 'D'): -0.459964,
#  ('prev_word.lower=)', 'T'): -0.582286,
#  ('word.lower=retrospectively', 'O'): 0.001346,
#  ('word[-3:]=ely', 'O'): 0.278586,
#  ('word[-2:]=ly', 'O'): 0.613863,
#  ('word[-2:]=ly', 'D'): 0.059786,
#  ('word[-2:]=ly', 'T'): -0.673649,
#  ('word.pos=ADV', 'O'): -0.18999,
#  ('word.pos=ADV', 'D'): 0.205684,
#  ('word.pos=ADV', 'T'): -0.015694,
#  ('prev_word.lower=were', 'O'): 0.313134,
#  ('prev_word.lower=were', 'D'): -0.088609,
#  ('prev_word.pos=AUX', 'O'): -0.381622,
#  ('prev_word.pos=AUX', 'D'): 0.120622,
#  ('prev_word.pos=AUX', 'T'): 0.261,
#  ('word.lower=analyzed', 'O'): 0.048865,
#  ('word[-3:]=zed', 'O'): 0.199984,
#  ('word[-3:]=zed', 'T'): 0.347145,
#  ('word[-2:]=ed', 'O'): 0.525934,
#  ('word[-2:]=ed', 'D'): -0.42488,
#  ('word[-2:]=ed', 'T'): -0.101055,
#  ('word.pos=VERB', 'O'): 0.289349,
#  ('word.pos=VERB', 'D'): -0.060509,
#  ('word.pos=VERB', 'T'): -0.22884,
#  ('prev_word.lower=retrospectively', 'O'): 0.001573,
#  ('prev_word.pos=ADV', 'O'): 0.30502,
#  ('prev_word.pos=ADV', 'D'): -0.407859,
#  ('prev_word.pos=ADV', 'T'): 0.102839,
#  ('word.lower=for', 'O'): 2.338944,
#  ('word.lower=for', 'T'): -0.620045,
#  ('word[-3:]=for', 'O'): 2.303606,
#  ('word[-3:]=for', 'T'): -0.609954,
#  ('prev_word.lower=analyzed', 'O'): 0.046005,
#  ('prev_word.pos=VERB', 'O'): -0.221741,
#  ('prev_word.pos=VERB', 'D'): 0.089878,
#  ('prev_word.pos=VERB', 'T'): 0.131863,
#  ('word.lower=delivery', 'O'): 0.551821,
#  ('word.lower=delivery', 'T'): -0.252774,
#  ('word[-3:]=ery', 'O'): -0.396973,
#  ('word[-3:]=ery', 'D'): -0.836348,
#  ('word[-3:]=ery', 'T'): 1.233321,
#  ('word[-2:]=ry', 'O'): -0.496315,
#  ('word[-2:]=ry', 'D'): 0.332023,
#  ('word[-2:]=ry', 'T'): 0.164292,
#  ('prev_word.lower=for', 'O'): -0.95593,
#  ('prev_word.lower=for', 'D'): 1.359326,
#  ('prev_word.lower=for', 'T'): -0.403396,
#  ('word.lower=route', 'O'): 0.076543,
#  ('word[-3:]=ute', 'O'): 0.013068,
#  ('word[-3:]=ute', 'D'): 0.651116,
#  ('word[-2:]=te', 'O'): -0.020496,
#  ('word[-2:]=te', 'D'): -0.172683,
#  ('word[-2:]=te', 'T'): 0.193179,
#  ('prev_word.lower=delivery', 'O'): 0.298454,
#  ('word.lower=,', 'O'): 0.870686,
#  ('word.lower=,', 'D'): -0.68889,
#  ('word.lower=,', 'T'): -0.181797,
#  ('word[-3:]=,', 'O'): 0.870686,
#  ('word[-3:]=,', 'D'): -0.68889,
#  ('word[-3:]=,', 'T'): -0.181797,
#  ('word[-2:]=,', 'O'): 0.870686,
#  ('word[-2:]=,', 'D'): -0.68889,
#  ('word[-2:]=,', 'T'): -0.181797,
#  ('prev_word.lower=route', 'O'): 0.022407,
#  ('word.lower=indication', 'O'): 0.071136,
#  ('word[-3:]=ion', 'O'): -0.573565,
#  ('word[-3:]=ion', 'D'): 0.080962,
#  ('word[-3:]=ion', 'T'): 0.492603,
#  ('word[-2:]=on', 'O'): 0.073736,
#  ('word[-2:]=on', 'D'): -0.01081,
#  ('word[-2:]=on', 'T'): -0.062926,
#  ('prev_word.lower=,', 'O'): -0.68945,
#  ('prev_word.lower=,', 'D'): 0.124669,
#  ('prev_word.lower=,', 'T'): 0.564781,
#  ('prev_word.lower=indication', 'O'): 0.010101,
#  ('word.lower=cesarean', 'O'): -0.035972,
#  ('word.lower=cesarean', 'T'): 0.076712,
#  ('word[-3:]=ean', 'O'): 0.1538,
#  ('word[-3:]=ean', 'T'): 0.039346,
#  ('word[-2:]=an', 'O'): 0.108499,
#  ('word[-2:]=an', 'D'): -0.646967,
#  ('word[-2:]=an', 'T'): 0.538468,
#  ('prev_word.lower=cesarean', 'O'): -0.000607,
#  ('prev_word.lower=cesarean', 'T'): 0.05397,
#  ('word.lower=gestational', 'O'): 0.060308,
#  ('word.lower=gestational', 'D'): 0.005148,
#  ('word[-3:]=nal', 'O'): -0.418323,
#  ('word[-3:]=nal', 'D'): 0.227798,
#  ('word[-3:]=nal', 'T'): 0.190525,
#  ('word[-2:]=al', 'O'): -0.304791,
#  ('word[-2:]=al', 'D'): 0.206174,
#  ('word[-2:]=al', 'T'): 0.098617,
#  ('word.lower=age', 'O'): 0.490804,
#  ('word[-3:]=age', 'O'): -0.115029,
#  ('word[-3:]=age', 'D'): 0.137011,
#  ('word[-3:]=age', 'T'): -0.021983,
#  ('word[-2:]=ge', 'O'): -0.10059,
#  ('word[-2:]=ge', 'D'): 0.25978,
#  ('word[-2:]=ge', 'T'): -0.15919,
#  ('prev_word.lower=gestational', 'O'): 0.048786,
#  ('prev_word.lower=gestational', 'D'): 0.010086,
#  ('prev_word.lower=age', 'O'): 0.129928,
#  ('word.lower=parity', 'O'): 0.005052,
#  ('prev_word.lower=parity', 'O'): 0.00108,
#  ('word.lower=and', 'O'): 0.564458,
#  ('word.lower=and', 'D'): -0.374812,
#  ('word.lower=and', 'T'): -0.189646,
#  ('word[-3:]=and', 'O'): 0.576837,
#  ('word[-3:]=and', 'D'): -0.39372,
#  ('word[-3:]=and', 'T'): -0.183117,
#  ('word[-2:]=nd', 'O'): 0.742182,
#  ('word[-2:]=nd', 'D'): -0.351794,
#  ('word[-2:]=nd', 'T'): -0.390388,
#  ('word.lower=practice', 'O'): 0.212273,
#  ('word[-3:]=ice', 'O'): 0.30592,
#  ('word[-3:]=ice', 'D'): -0.02522,
#  ('word[-2:]=ce', 'O'): 0.426456,
#  ('word[-2:]=ce', 'D'): -0.070131,
#  ('word[-2:]=ce', 'T'): -0.356325,
#  ('prev_word.lower=and', 'O'): -0.671732,
#  ('prev_word.lower=and', 'D'): 0.237647,
#  ('prev_word.lower=and', 'T'): 0.434085,
#  ('word.lower=group', 'O'): 0.672976,
#  ('word[-3:]=oup', 'O'): 0.114266,
#  ('word[-3:]=oup', 'D'): 0.242271,
#  ('word[-2:]=up', 'O'): 0.455536,
#  ('word[-2:]=up', 'D'): -0.013779,
#  ('prev_word.lower=practice', 'O'): 0.075862,
#  ('prev_word.lower=group', 'O'): 0.403732,
#  ('word.lower=to', 'O'): 0.58173,
#  ('word.lower=to', 'D'): -0.116697,
#  ('word.lower=to', 'T'): -0.465032,
#  ('word[-3:]=to', 'O'): 0.486755,
#  ('word[-3:]=to', 'D'): -0.094355,
#  ('word[-3:]=to', 'T'): -0.392399,
#  ('word[-2:]=to', 'O'): 0.677266,
#  ('word[-2:]=to', 'D'): -0.258289,
#  ('word[-2:]=to', 'T'): -0.418977,
#  ('word.pos=PART', 'O'): -0.057159,
#  ('word.pos=PART', 'D'): 0.377643,
#  ('word.pos=PART', 'T'): -0.320484,
#  ('word.lower=reflect', 'O'): 0.032655,
#  ('word[-3:]=ect', 'O'): 0.418158,
#  ('word[-3:]=ect', 'T'): 0.112538,
#  ('word[-2:]=ct', 'O'): 0.078686,
#  ('word[-2:]=ct', 'D'): 0.341116,
#  ('word[-2:]=ct', 'T'): -0.419801,
#  ('prev_word.lower=to', 'O'): -0.396821,
#  ('prev_word.lower=to', 'D'): 0.30333,
#  ('prev_word.lower=to', 'T'): 0.09349,
#  ('prev_word.pos=PART', 'O'): 0.43538,
#  ('prev_word.pos=PART', 'D'): 0.130674,
#  ('prev_word.pos=PART', 'T'): -0.566054,
#  ('word.lower=risk', 'O'): 0.593208,
#  ('word[-3:]=isk', 'O'): 0.609063,
#  ('word[-2:]=sk', 'O'): 0.668728,
#  ('prev_word.lower=reflect', 'O'): 0.056443,
#  ('word.lower=status', 'O'): 0.289841,
#  ('word.lower=status', 'D'): -0.091607,
#  ('word[-3:]=tus', 'O'): 0.364771,
#  ('word[-3:]=tus', 'D'): -0.056057,
#  ('word[-2:]=us', 'O'): -0.65023,
#  ('word[-2:]=us', 'D'): 0.763688,
#  ('word[-2:]=us', 'T'): -0.113458,
#  ('prev_word.lower=risk', 'O'): 0.291344,
#  ('prev_word.lower=status', 'O'): 0.034518,
#  ('prev_word.lower=status', 'D'): 0.067093,
#  ('END', 'O'): 0.363899,
#  ('END', 'D'): -0.441483,
#  ('END', 'T'): 0.077584,
#  ('word[-3:]=The', 'O'): 0.376719,
#  ('word[-3:]=The', 'T'): -0.150217,
#  ('word.lower=total', 'O'): 0.103978,
#  ('word.lower=total', 'D'): 0.018985,
#  ('word.lower=total', 'T'): -0.122963,
#  ('word[-3:]=tal', 'O'): 0.126916,
#  ('word[-3:]=tal', 'D'): 0.224358,
#  ('word[-3:]=tal', 'T'): -0.351274,
#  ('prev_word.lower=total', 'O'): -0.153433,
#  ('prev_word.lower=total', 'D'): 0.004005,
#  ('prev_word.lower=total', 'T'): 0.149428,
#  ('word.lower=rate', 'O'): 0.583962,
#  ('word[-3:]=ate', 'O'): -0.37237,
#  ('word[-3:]=ate', 'D'): -0.567594,
#  ('word[-3:]=ate', 'T'): 0.939964,
#  ('word.lower=was', 'O'): 0.992138,
#  ('word[-3:]=was', 'O'): 0.992138,
#  ('word[-2:]=as', 'O'): -0.217243,
#  ('word[-2:]=as', 'D'): 1.061167,
#  ('word[-2:]=as', 'T'): -0.843924,
#  ('prev_word.lower=rate', 'O'): 0.262866,
#  ('word.lower=14.4', 'O'): 0.000882,
#  ('word[-3:]=4.4', 'O'): 0.002409,
#  ('word[-2:]=.4', 'O'): 0.050338,
#  ('prev_word.lower=was', 'O'): 0.728751,
#  ('word.lower=%', 'O'): 0.389268,
#  ('word.lower=%', 'T'): -0.104728,
#  ('word[-3:]=%', 'O'): 0.389268,
#  ('word[-3:]=%', 'T'): -0.104728,
#  ('word[-2:]=%', 'O'): 0.389268,
#  ('word[-2:]=%', 'T'): -0.104728,
#  ('prev_word.lower=14.4', 'O'): 0.001805,
#  ('prev_word.lower=%', 'O'): 0.398732,
#  ('prev_word.lower=%', 'T'): -0.132287,
#  ('word.lower=344', 'O'): 0.005617,
#  ('word[-3:]=344', 'O'): 0.014073,
#  ('word[-2:]=44', 'O'): 0.043335,
#  ('prev_word.lower=344', 'O'): 0.012144,
#  ('word.lower=primary', 'O'): 0.051708,
#  ('word.lower=primary', 'D'): -0.117281,
#  ('word.lower=primary', 'T'): 0.065573,
#  ('word[-3:]=ary', 'O'): 0.058709,
#  ('word[-3:]=ary', 'D'): 0.070259,
#  ('word[-3:]=ary', 'T'): -0.128968,
#  ('prev_word.lower=primary', 'O'): -0.46872,
#  ('prev_word.lower=primary', 'D'): 0.461466,
#  ('prev_word.lower=primary', 'T'): 0.007254,
#  ('word.lower=11.4', 'O'): 0.000863,
#  ('word[-3:]=1.4', 'O'): 0.004993,
#  ('prev_word.lower=11.4', 'O'): 0.001798,
#  ('word.lower=244', 'O'): 0.000533,
#  ('word[-3:]=244', 'O'): 0.000533,
#  ('prev_word.lower=244', 'O'): 0.000435,
#  ('word.lower=2144', 'O'): 0.005106,
#  ('word[-3:]=144', 'O'): 0.020897,
#  ('prev_word.lower=2144', 'O'): 0.011815,
#  ('word.lower=abnormal', 'O'): 0.118748,
#  ('word[-3:]=mal', 'O'): 0.763516,
#  ('word[-3:]=mal', 'D'): -0.213294,
#  ('word.lower=presentation', 'O'): 0.151538,
#  ('prev_word.lower=abnormal', 'O'): 0.160262,
#  ('prev_word.lower=presentation', 'O'): 0.023056,
#  ('word.lower=most', 'O'): 0.095948,
#  ('word[-3:]=ost', 'O'): 0.205941,
#  ('word[-2:]=st', 'O'): 0.568544,
#  ('word[-2:]=st', 'D'): -0.607926,
#  ('word[-2:]=st', 'T'): 0.039382,
#  ('word.lower=common', 'O'): -0.337316,
#  ('word.lower=common', 'D'): 0.472578,
#  ('word[-3:]=mon', 'O'): -0.273386,
#  ('word[-3:]=mon', 'D'): 0.427223,
#  ('prev_word.lower=most', 'O'): 0.225547,
#  ('prev_word.lower=common', 'O'): -0.555278,
#  ('prev_word.lower=common', 'D'): 0.705819,
#  ('word.lower=25.6', 'O'): 0.002858,
#  ('word[-3:]=5.6', 'O'): 0.002858,
#  ('word[-2:]=.6', 'O'): -0.112353,
#  ('word[-2:]=.6', 'T'): 0.133527,
#  ('prev_word.lower=25.6', 'O'): 0.00246,
#  ('word.lower=88', 'O'): 0.000562,
#  ('word[-3:]=88', 'O'): 0.000562,
#  ('word[-2:]=88', 'O'): 0.003512,
#  ('prev_word.lower=88', 'O'): 0.000429,
#  ('word.lower=``', 'O'): 0.473519,
#  ('word.lower=``', 'T'): -0.123104,
#  ('word[-3:]=``', 'O'): 0.473519,
#  ('word[-3:]=``', 'T'): -0.123104,
#  ('word[-2:]=``', 'O'): 0.473519,
#  ('word[-2:]=``', 'T'): -0.123104,
#  ('word.lower=corrected', 'O'): 0.03312,
#  ('word[-3:]=ted', 'O'): -0.107178,
#  ('word[-3:]=ted', 'D'): 0.156795,
#  ('word[-3:]=ted', 'T'): -0.049617,
#  ('prev_word.lower=``', 'O'): 0.490142,
#  ('prev_word.lower=``', 'D'): -0.275796,
#  ('prev_word.lower=``', 'T'): -0.214345,
#  ("word.lower=''", 'O'): 0.394841,
#  ("word.lower=''", 'T'): -0.113611,
#  ("word[-3:]=''", 'O'): 0.394841,
#  ("word[-3:]=''", 'T'): -0.113611,
#  ("word[-2:]=''", 'O'): 0.394841,
#  ("word[-2:]=''", 'T'): -0.113611,
#  ('prev_word.lower=corrected', 'O'): 0.042702,
#  ("prev_word.lower=''", 'O'): 0.212339,
#  ("prev_word.lower=''", 'T'): -0.053546,
#  ('word.lower=maternal-fetal', 'O'): 0.017272,
#  ('word.lower=medicine', 'O'): 0.902362,
#  ('word.lower=medicine', 'T'): -0.698726,
#  ('word[-3:]=ine', 'O'): -0.495346,
#  ('word[-3:]=ine', 'D'): -0.465062,
#  ('word[-3:]=ine', 'T'): 0.960407,
#  ('word[-2:]=ne', 'O'): -0.356213,
#  ('word[-2:]=ne', 'D'): -0.486865,
#  ('word[-2:]=ne', 'T'): 0.843078,
#  ('prev_word.lower=maternal-fetal', 'O'): 0.017003,
#  ('prev_word.lower=medicine', 'O'): 0.236277,
#  ('prev_word.lower=medicine', 'T'): -0.14542,
#  ('word.lower=transported', 'O'): 0.007385,
#  ('word.lower=patients', 'O'): 1.553701,
#  ('word.lower=patients', 'D'): -0.378326,
#  ('word[-3:]=nts', 'O'): -0.614341,
#  ('word[-3:]=nts', 'D'): -0.077109,
#  ('word[-3:]=nts', 'T'): 0.69145,
#  ('word[-2:]=ts', 'O'): 0.395557,
#  ('word[-2:]=ts', 'D'): -0.214354,
#  ('word[-2:]=ts', 'T'): -0.181203,
#  ('prev_word.lower=transported', 'O'): 0.006632,
#  ('word.lower=excluded', 'O'): 0.011069,
#  ('word[-3:]=ded', 'O'): -0.133322,
#  ('word[-3:]=ded', 'T'): 0.484567,
#  ('prev_word.lower=patients', 'O'): 1.110553,
#  ('prev_word.lower=excluded', 'O'): 0.022292,
#  ('word.lower=12.4', 'O'): 0.001867,
#  ('word[-3:]=2.4', 'O'): 0.002795,
#  ('prev_word.lower=12.4', 'O'): 0.00208,
#  ('word.lower=273', 'O'): 0.000532,
#  ('word[-3:]=273', 'O'): 0.000532,
#  ('word[-2:]=73', 'O'): 0.012535,
#  ('prev_word.lower=273', 'O'): 0.000818,
#  ('word.lower=2194', 'O'): 0.002508,
#  ('word[-3:]=194', 'O'): 0.002508,
#  ('word[-2:]=94', 'O'): 0.009993,
#  ('prev_word.lower=2194', 'O'): 0.002125,
#  ('word.lower=9.6', 'O'): 0.010086,
#  ('word[-3:]=9.6', 'O'): 0.010086,
#  ('prev_word.lower=9.6', 'O'): 0.008216,
#  ('word.lower=190', 'O'): 0.003312,
#  ('word[-3:]=190', 'O'): 0.016759,
#  ('word[-2:]=90', 'O'): 0.064209,
#  ('prev_word.lower=190', 'O'): -0.157835,
#  ('prev_word.lower=190', 'D'): 0.159468,
#  ('word.lower=1975', 'O'): 0.025246,
#  ('word[-3:]=975', 'O'): 0.025246,
#  ('word[-2:]=75', 'O'): 0.063312,
#  ('prev_word.lower=1975', 'O'): 0.032633,
#  ('word.lower=arrest', 'O'): -0.206447,
#  ('word.lower=arrest', 'D'): 0.240729,
#  ('word[-3:]=est', 'O'): 0.301309,
#  ('word[-3:]=est', 'D'): -0.044347,
#  ('prev_word.lower=arrest', 'O'): -0.082757,
#  ('prev_word.lower=arrest', 'D'): 0.100395,
#  ('word.lower=dilation', 'O'): 0.033027,
#  ('prev_word.lower=dilation', 'O'): 0.001715,
#  ('word.lower=both', 'O'): 0.18483,
#  ('word[-3:]=oth', 'O'): 0.090964,
#  ('word[-3:]=oth', 'T'): -0.008922,
#  ('word[-2:]=th', 'O'): 1.108189,
#  ('word[-2:]=th', 'D'): -0.822759,
#  ('word[-2:]=th', 'T'): -0.28543,
#  ('prev_word.lower=both', 'O'): -0.317798,
#  ('prev_word.lower=both', 'D'): 0.176403,
#  ('prev_word.lower=both', 'T'): 0.141395,
#  ('word.lower=subgroups', 'O'): 0.006356,
#  ('word[-3:]=ups', 'O'): 0.109128,
#  ('word[-3:]=ups', 'D'): 0.052938,
#  ('word[-2:]=ps', 'O'): -0.305867,
#  ('word[-2:]=ps', 'D'): 0.456626,
#  ('word[-2:]=ps', 'T'): -0.15076,
#  ('prev_word.lower=subgroups', 'O'): 0.006232,
#  ('word.lower=23.4', 'O'): 0.00258,
#  ('word[-3:]=3.4', 'O'): 0.017419,
#  ('prev_word.lower=23.4', 'O'): 0.000545,
#  ('word.lower=24.6', 'O'): 0.001596,
#  ('word[-3:]=4.6', 'O'): 0.001596,
#  ('prev_word.lower=24.6', 'O'): 0.00075,
#  ('word.lower=respectively', 'O'): 0.060859,
#  ('prev_word.lower=respectively', 'O'): 0.038438,
#  ('word.lower=rates', 'O'): 0.448273,
#  ('word[-3:]=tes', 'O'): -0.362888,
#  ('word[-3:]=tes', 'D'): 0.736837,
#  ('word[-3:]=tes', 'T'): -0.373949,
#  ('word[-2:]=es', 'O'): -0.176253,
#  ('word[-2:]=es', 'D'): 0.154325,
#  ('word[-2:]=es', 'T'): 0.021928,
#  ('prev_word.lower=rates', 'O'): 0.212069,
#  ('word.lower=tertiary', 'O'): 0.035997,
#  ('word.lower=care', 'O'): 0.254696,
#  ('word.lower=care', 'T'): 0.046491,
#  ('word[-3:]=are', 'O'): 0.794465,
#  ('word[-3:]=are', 'T'): -0.16329,
#  ('prev_word.lower=tertiary', 'O'): 0.028572,
#  ('word.lower=hospitals', 'O'): 0.053871,
#  ('word[-3:]=als', 'O'): 0.224643,
#  ('word[-3:]=als', 'T'): 0.07051,
#  ('word[-2:]=ls', 'O'): 0.700998,
#  ('word[-2:]=ls', 'D'): -0.668685,
#  ('word[-2:]=ls', 'T'): -0.032313,
#  ('prev_word.lower=care', 'O'): 0.193584,
#  ('word.lower=should', 'O'): 0.393052,
#  ('word[-3:]=uld', 'O'): 0.64925,
#  ('word[-2:]=ld', 'O'): 0.142343,
#  ('word[-2:]=ld', 'D'): 0.31042,
#  ('word[-2:]=ld', 'T'): -0.452763,
#  ('prev_word.lower=hospitals', 'O'): 0.029206,
#  ('word.lower=be', 'O'): 0.368233,
#  ('word[-3:]=be', 'O'): 0.368233,
#  ('word[-2:]=be', 'O'): 0.4571,
#  ('word[-2:]=be', 'T'): -0.059169,
#  ('prev_word.lower=should', 'O'): 0.173902,
#  ('prev_word.lower=should', 'T'): -0.011638,
#  ('word.lower=compared', 'O'): 0.355602,
#  ('word[-3:]=red', 'O'): 0.417446,
#  ('word[-3:]=red', 'D'): -0.168815,
#  ('word[-3:]=red', 'T'): -0.248632,
#  ('prev_word.lower=be', 'O'): 0.083564,
#  ('prev_word.lower=be', 'D'): 0.035217,
#  ('word.lower=with', 'O'): 0.59385,
#  ('word.lower=with', 'D'): -0.718888,
#  ('word.lower=with', 'T'): 0.125038,
#  ('word[-3:]=ith', 'O'): 0.597519,
#  ('word[-3:]=ith', 'D'): -0.719425,
#  ('word[-3:]=ith', 'T'): 0.121906,
#  ('prev_word.lower=compared', 'O'): 0.347377,
#  ('prev_word.lower=with', 'O'): -1.600033,
#  ('prev_word.lower=with', 'D'): 0.964899,
#  ('prev_word.lower=with', 'T'): 0.635134,
#  ('word.lower=community', 'O'): 0.124007,
#  ('prev_word.lower=community', 'O'): 0.120072,
#  ('word.lower=only', 'O'): 0.120205,
#  ('word[-3:]=nly', 'O'): 0.135342,
#  ('word.lower=after', 'O'): 1.249614,
#  ('word.lower=after', 'D'): -0.498167,
#  ('word[-3:]=ter', 'O'): 1.010891,
#  ('word[-3:]=ter', 'D'): -0.617984,
#  ('word[-3:]=ter', 'T'): -0.392907,
#  ('word[-2:]=er', 'O'): -0.09161,
#  ('word[-2:]=er', 'D'): 0.74228,
#  ('word[-2:]=er', 'T'): -0.65067,
#  ('prev_word.lower=only', 'O'): 0.119676,
#  ('word.lower=correcting', 'O'): 0.013933,
#  ('word[-3:]=ing', 'O'): 0.655776,
#  ('word[-3:]=ing', 'D'): -0.272238,
#  ('word[-3:]=ing', 'T'): -0.383538,
#  ('word[-2:]=ng', 'O'): -0.0122,
#  ('word[-2:]=ng', 'D'): -0.197542,
#  ('word[-2:]=ng', 'T'): 0.209742,
#  ('prev_word.lower=after', 'O'): -0.192785,
#  ('prev_word.lower=after', 'D'): -0.104475,
#  ('prev_word.lower=after', 'T'): 0.29726,
#  ('prev_word.lower=correcting', 'O'): 0.018898,
#  ('word.lower=dissimilar', 'O'): 0.030565,
#  ('word[-3:]=lar', 'O'): -0.269341,
#  ('word[-3:]=lar', 'D'): 0.372246,
#  ('word[-3:]=lar', 'T'): -0.102905,
#  ('word[-2:]=ar', 'O'): -0.245118,
#  ('word[-2:]=ar', 'D'): 0.260534,
#  ('word[-2:]=ar', 'T'): -0.015416,
#  ('word.lower=patient', 'O'): 0.444499,
#  ('word[-3:]=ent', 'O'): 0.463026,
#  ('word[-3:]=ent', 'D'): -0.680909,
#  ('word[-3:]=ent', 'T'): 0.217883,
#  ('prev_word.lower=dissimilar', 'O'): 0.021334,
#  ('word.lower=groups', 'O'): 0.240428,
#  ('prev_word.lower=patient', 'O'): 0.381245,
#  ('prev_word.lower=groups', 'O'): 0.07622,
#  ('word[-3:]=In', 'O'): 0.075569,
#  ('word[-2:]=In', 'O'): 0.075569,
#  ('word.lower=third', 'O'): 0.011538,
#  ('word[-3:]=ird', 'O'): 0.034814,
#  ('word[-2:]=rd', 'O'): 0.056518,
#  ('word[-2:]=rd', 'D'): -0.069201,
#  ('word[-2:]=rd', 'T'): 0.012683,
#  ('word.lower=trimester', 'O'): 0.016332,
#  ('prev_word.lower=third', 'O'): 0.016125,
#  ('prev_word.lower=trimester', 'O'): 0.004518,
#  ('word.lower=amniotic', 'O'): 0.007823,
#  ('word.lower=amniotic', 'D'): 0.053486,
#  ('word[-3:]=tic', 'O'): -0.19438,
#  ('word[-3:]=tic', 'D'): -0.15832,
#  ('word[-3:]=tic', 'T'): 0.3527,
#  ('word[-2:]=ic', 'O'): -0.733754,
#  ('word[-2:]=ic', 'D'): 0.39728,
#  ('word[-2:]=ic', 'T'): 0.336474,
#  ('word.lower=fluid', 'O'): 0.145457,
#  ('word.lower=fluid', 'D'): -0.039288,
#  ('word[-3:]=uid', 'O'): 0.161168,
#  ('word[-3:]=uid', 'D'): -0.046891,
#  ('word[-2:]=id', 'O'): -0.708338,
#  ('word[-2:]=id', 'D'): 0.392721,
#  ('word[-2:]=id', 'T'): 0.315617,
#  ('prev_word.lower=amniotic', 'O'): 0.036943,
#  ('prev_word.lower=amniotic', 'D'): 0.030698,
#  ('word.lower=index', 'O'): 0.212588,
#  ('word[-3:]=dex', 'O'): 0.212588,
#  ('word[-2:]=ex', 'O'): 0.10931,
#  ('word[-2:]=ex', 'D'): 0.115788,
#  ('word[-2:]=ex', 'T'): -0.225098,
#  ('prev_word.lower=fluid', 'O'): 0.051933,
#  ('prev_word.lower=fluid', 'D'): 0.010762,
#  ('prev_word.lower=index', 'O'): 0.083425,
#  ('word.lower=afi', 'O'): 0.077317,
#  ('word[-3:]=AFI', 'O'): 0.077317,
#  ('word[-2:]=FI', 'O'): 0.077317,
#  ('word.isupper=True', 'O'): 0.409385,
#  ('word.isupper=True', 'D'): -0.131233,
#  ('word.isupper=True', 'T'): -0.278153,
#  ('prev_word.lower=afi', 'O'): 0.036903,
#  ('prev_word.isupper=True', 'O'): 0.597496,
#  ('prev_word.isupper=True', 'D'): -0.481144,
#  ('prev_word.isupper=True', 'T'): -0.116352,
#  ('word.lower=may', 'O'): 0.479449,
#  ('word[-3:]=may', 'O'): 0.475435,
#  ('word[-2:]=ay', 'O'): 0.467261,
#  ('word[-2:]=ay', 'D'): -0.288637,
#  ('word[-2:]=ay', 'T'): -0.178624,
#  ('prev_word.lower=may', 'O'): 0.520688,
#  ('word.lower=affected', 'O'): 0.030198,
#  ('word.lower=by', 'O'): 0.698231,
#  ('word.lower=by', 'D'): -0.251183,
#  ('word.lower=by', 'T'): -0.447048,
#  ('word[-3:]=by', 'O'): 0.690604,
#  ('word[-3:]=by', 'D'): -0.247823,
#  ('word[-3:]=by', 'T'): -0.442781,
#  ('word[-2:]=by', 'O'): 0.716169,
#  ('word[-2:]=by', 'D'): -0.266065,
#  ('word[-2:]=by', 'T'): -0.450104,
#  ('prev_word.lower=affected', 'O'): 0.037973,
#  ('word.lower=maternal', 'O'): 0.318808,
#  ('prev_word.lower=by', 'O'): -0.49837,
#  ('prev_word.lower=by', 'D'): -0.70901,
#  ('prev_word.lower=by', 'T'): 1.20738,
#  ('prev_word.lower=maternal', 'O'): 0.151972,
#  ('prev_word.lower=maternal', 'D'): -0.050244,
#  ('word.lower=we', 'O'): 0.251305,
#  ('word[-3:]=We', 'O'): 0.135199,
#  ('word[-2:]=We', 'O'): 0.135199,
#  ('word.lower=hypothesize', 'O'): 0.003664,
#  ('word[-3:]=ize', 'O'): 0.132771,
#  ('word[-2:]=ze', 'O'): 0.145156,
#  ('prev_word.lower=we', 'O'): 0.208812,
#  ('word.lower=that', 'O'): 0.715734,
#  ('word.lower=that', 'T'): -0.313979,
#  ('word[-3:]=hat', 'O'): 0.749634,
#  ('word[-3:]=hat', 'T'): -0.32552,
#  ('word.pos=SCONJ', 'O'): 1.291763,
#  ('word.pos=SCONJ', 'T'): -0.452341,
#  ('prev_word.lower=hypothesize', 'O'): 0.003491,
#  ('word.lower=as', 'O'): 0.673023,
#  ('word.lower=as', 'D'): -0.531166,
#  ('word.lower=as', 'T'): -0.141857,
#  ('word[-3:]=as', 'O'): 0.640996,
#  ('word[-3:]=as', 'D'): -0.513414,
#  ('word[-3:]=as', 'T'): -0.127582,
#  ('prev_word.lower=that', 'O'): -0.874116,
#  ('prev_word.lower=that', 'D'): -0.381833,
#  ('prev_word.lower=that', 'T'): 1.255949,
#  ('prev_word.pos=SCONJ', 'O'): -0.333716,
#  ('prev_word.pos=SCONJ', 'D'): -0.030547,
#  ('prev_word.pos=SCONJ', 'T'): 0.364262,
#  ('word.lower=temperature', 'O'): 0.045636,
#  ('word[-3:]=ure', 'O'): -0.883006,
#  ('word[-3:]=ure', 'D'): 0.334877,
#  ('word[-3:]=ure', 'T'): 0.548129,
#  ('prev_word.lower=as', 'O'): -0.050437,
#  ('prev_word.lower=as', 'D'): 0.218866,
#  ('prev_word.lower=as', 'T'): -0.168429,
#  ('word.lower=increases', 'O'): 0.140357,
#  ('word[-3:]=ses', 'O'): -0.41057,
#  ('word[-3:]=ses', 'D'): 0.877136,
#  ('word[-3:]=ses', 'T'): -0.466566,
#  ('prev_word.lower=temperature', 'O'): 0.025662,
#  ('word.lower=there', 'O'): 0.060917,
#  ('prev_word.lower=increases', 'O'): 0.025968,
#  ('word.lower=would', 'O'): 0.226953,
#  ('prev_word.lower=there', 'O'): 0.053989,
#  ('prev_word.lower=would', 'O'): 0.197873,
#  ('word.lower=a', 'O'): 0.361191,
#  ('word.lower=a', 'D'): -0.223208,
#  ('word.lower=a', 'T'): -0.137982,
#  ('word[-3:]=a', 'O'): 0.331415,
#  ('word[-3:]=a', 'D'): -0.313069,
#  ('word[-3:]=a', 'T'): -0.018347,
#  ('word[-2:]=a', 'O'): 0.331415,
#  ('word[-2:]=a', 'D'): -0.313069,
#  ('word[-2:]=a', 'T'): -0.018347,
#  ('word.lower=concomitant', 'O'): -0.135674,
#  ('word.lower=concomitant', 'D'): 0.181316,
#  ('word.lower=concomitant', 'T'): -0.045642,
#  ('word[-3:]=ant', 'O'): -0.501276,
#  ('word[-3:]=ant', 'D'): 0.490891,
#  ('word[-3:]=ant', 'T'): 0.010386,
#  ('prev_word.lower=a', 'O'): -0.339778,
#  ('prev_word.lower=a', 'D'): 0.205737,
#  ('prev_word.lower=a', 'T'): 0.134041,
#  ('word.lower=decrease', 'O'): 0.047524,
#  ('word[-3:]=ase', 'O'): -0.623929,
#  ('word[-3:]=ase', 'D'): 0.478096,
#  ('word[-3:]=ase', 'T'): 0.145833,
#  ('word[-2:]=se', 'O'): 0.53437,
#  ('word[-2:]=se', 'D'): -0.52816,
#  ('word[-2:]=se', 'T'): -0.006211,
#  ('prev_word.lower=concomitant', 'O'): -0.04107,
#  ('prev_word.lower=concomitant', 'D'): 0.136568,
#  ('prev_word.lower=concomitant', 'T'): -0.095498,
#  ('prev_word.lower=decrease', 'O'): 0.024893,
#  ('word.lower=from', 'O'): 0.564465,
#  ('word.lower=from', 'D'): -0.213186,
#  ('word[-3:]=rom', 'O'): 0.564465,
#  ('word[-3:]=rom', 'D'): -0.213186,
#  ('word[-2:]=om', 'O'): 0.638536,
#  ('word[-2:]=om', 'D'): -0.156505,
#  ('word.lower=june', 'O'): 0.01992,
#  ('word[-3:]=une', 'O'): -0.104792,
#  ('word[-3:]=une', 'D'): 0.467799,
#  ('prev_word.lower=from', 'O'): 0.083374,
#  ('prev_word.lower=from', 'D'): 0.036241,
#  ('prev_word.lower=from', 'T'): -0.119615,
#  ('word.lower=11', 'O'): 0.030291,
#  ('word[-3:]=11', 'O'): 0.030291,
#  ('word[-2:]=11', 'O'): -0.175069,
#  ('word[-2:]=11', 'T'): 0.20859,
#  ('prev_word.lower=june', 'O'): 0.002375,
#  ('prev_word.lower=11', 'O'): 0.041689,
#  ('word.lower=august', 'O'): 0.014237,
#  ('word[-3:]=ust', 'O'): 0.036061,
#  ('word.lower=16', 'O'): 0.049966,
#  ('word[-3:]=16', 'O'): 0.049966,
#  ('word[-2:]=16', 'O'): 0.076883,
#  ('word[-2:]=16', 'T'): -0.014291,
#  ('prev_word.lower=august', 'O'): 0.003681,
#  ('prev_word.lower=16', 'O'): -0.124396,
#  ('prev_word.lower=16', 'T'): 0.146493,
#  ('word.lower=1993', 'O'): 0.025566,
#  ('word[-3:]=993', 'O'): 0.025566,
#  ('word[-2:]=93', 'O'): 0.044565,
#  ('prev_word.lower=1993', 'O'): 0.004619,
#  ('word.lower=during', 'O'): 0.790013,
#  ('prev_word.lower=during', 'O'): 0.213624,
#  ('prev_word.lower=during', 'D'): -0.29329,
#  ('prev_word.lower=during', 'T'): 0.079666,
#  ('word.lower=period', 'O'): 0.122485,
#  ('word[-3:]=iod', 'O'): 0.122485,
#  ('word[-2:]=od', 'O'): 0.187318,
#  ('word[-2:]=od', 'D'): -0.294071,
#  ('word[-2:]=od', 'T'): 0.106753,
#  ('prev_word.lower=period', 'O'): 0.049041,
#  ('word.lower=unusual', 'O'): 0.063648,
#  ('word[-3:]=ual', 'O'): 0.375534,
#  ('word[-3:]=ual', 'D'): -0.080603,
#  ('word.lower=high', 'O'): 0.141251,
#  ('word.lower=high', 'D'): 0.022492,
#  ('word[-3:]=igh', 'O'): 0.141251,
#  ('word[-3:]=igh', 'D'): 0.022492,
#  ('word[-2:]=gh', 'O'): 0.338313,
#  ('word[-2:]=gh', 'D'): -0.070936,
#  ('prev_word.lower=unusual', 'O'): 0.071841,
#  ('word.lower=heat', 'O'): 0.025188,
#  ('word[-3:]=eat', 'O'): 0.212378,
#  ('word[-3:]=eat', 'T'): -0.075113,
#  ('prev_word.lower=high', 'O'): 0.055112,
#  ('prev_word.lower=high', 'D'): 0.146535,
#  ('prev_word.lower=heat', 'O'): 0.023503,
#  ('word.lower=42', 'O'): 0.019453,
#  ('word[-3:]=42', 'O'): 0.019453,
#  ('word[-2:]=42', 'O'): 0.042626,
#  ('word.lower=women', 'O'): 0.295767,
#  ('word[-3:]=men', 'O'): 0.149306,
#  ('word[-3:]=men', 'D'): -0.129481,
#  ('word[-3:]=men', 'T'): -0.019825,
#  ('word[-2:]=en', 'O'): 0.156603,
#  ('word[-2:]=en', 'D'): -0.246885,
#  ('word[-2:]=en', 'T'): 0.090281,
#  ('prev_word.lower=42', 'O'): 0.02303,
#  ('prev_word.lower=women', 'O'): 0.146288,
#  ('word.lower=singleton', 'O'): 0.054767,
#  ('word[-3:]=ton', 'O'): 0.155135,
#  ('word.lower=pregnancies', 'O'): 0.076747,
#  ('word[-3:]=ies', 'O'): -0.527421,
#  ('word[-3:]=ies', 'D'): 0.432515,
#  ('word[-3:]=ies', 'T'): 0.094906,
#  ('prev_word.lower=singleton', 'O'): 0.029442,
#  ('word.lower=between', 'O'): 0.343593,
#  ('word[-3:]=een', 'O'): 0.576399,
#  ('prev_word.lower=pregnancies', 'O'): 0.007583,
#  ('word.lower=27', 'O'): 0.007817,
#  ('word[-3:]=27', 'O'): 0.007817,
#  ('word[-2:]=27', 'O'): 0.119822,
#  ('prev_word.lower=between', 'O'): 0.140271,
#  ('prev_word.lower=between', 'D'): -0.069864,
#  ('prev_word.lower=between', 'T'): -0.070407,
#  ('prev_word.lower=27', 'O'): -0.160018,
#  ('prev_word.lower=27', 'D'): 0.166231,
#  ('word.lower=40', 'O'): 0.034998,
#  ('word[-3:]=40', 'O'): 0.034998,
#  ('word[-2:]=40', 'O'): 0.120953,
#  ('prev_word.lower=40', 'O'): 0.04549,
#  ("word.lower='", 'O'): 0.116275,
#  ("word.lower='", 'T'): 0.036009,
#  ("word[-3:]='", 'O'): 0.116275,
#  ("word[-3:]='", 'T'): 0.036009,
#  ("word[-2:]='", 'O'): 0.116275,
#  ("word[-2:]='", 'T'): 0.036009,
#  ('word.lower=gestation', 'O'): 0.056308,
#  ("prev_word.lower='", 'O'): 0.147212,
#  ("prev_word.lower='", 'T'): 0.026151,
#  ('word.lower=undergoing', 'O'): 0.118437,
#  ('prev_word.lower=gestation', 'O'): 0.014238,
#  ('word.lower=serial', 'O'): 0.051978,
#  ('word[-3:]=ial', 'O'): -0.288086,
#  ('word[-3:]=ial', 'D'): 0.332998,
#  ('word[-3:]=ial', 'T'): -0.044913,
#  ('prev_word.lower=undergoing', 'O'): -0.007205,
#  ('prev_word.lower=undergoing', 'T'): 0.099823,
#  ('word.lower=antenatal', 'O'): -0.007783,
#  ('word.lower=antenatal', 'T'): 0.097482,
#  ('prev_word.lower=serial', 'O'): 0.055211,
#  ('word.lower=testing', 'O'): 0.166538,
#  ('prev_word.lower=antenatal', 'O'): 0.030993,
#  ('prev_word.lower=antenatal', 'T'): 0.075187,
#  ('word.lower=had', 'O'): 0.505198,
#  ('word[-3:]=had', 'O'): 0.505198,
#  ('word[-2:]=ad', 'O'): 0.092818,
#  ('word[-2:]=ad', 'D'): 0.32205,
#  ('prev_word.lower=testing', 'O'): 0.062072,
#  ('prev_word.lower=had', 'O'): -0.243411,
#  ('prev_word.lower=had', 'D'): 0.093023,
#  ('prev_word.lower=had', 'T'): 0.150388,
#  ('word.lower=determinations', 'O'): 0.032711,
#  ('word[-3:]=ons', 'O'): -0.5536,
#  ('word[-3:]=ons', 'D'): 0.472807,
#  ('word[-3:]=ons', 'T'): 0.080792,
#  ('word[-2:]=ns', 'O'): -0.184722,
#  ('word[-2:]=ns', 'D'): 0.103884,
#  ('word[-2:]=ns', 'T'): 0.080838,
#  ('word.lower=recorded', 'O'): 0.007766,
#  ('prev_word.lower=determinations', 'O'): 0.005376,
#  ('prev_word.lower=recorded', 'O'): 0.002546,
#  ('word.lower=least', 'O'): 0.025571,
#  ('word[-3:]=ast', 'O'): -0.299936,
#  ('word[-3:]=ast', 'D'): 0.284142,
#  ('word[-3:]=ast', 'T'): 0.015794,
#  ('word.lower=weekly', 'O'): 0.00644,
#  ('word[-3:]=kly', 'O'): 0.00644,
#  ('prev_word.lower=least', 'O'): 0.029634,
#  ('word.lower=daily', 'O'): 0.117117,
#  ('word[-3:]=ily', 'O'): 0.308153,
#  ('word[-3:]=ily', 'D'): -0.06654,
#  ('prev_word.lower=daily', 'O'): 0.146233,
#  ('word.lower=ambient', 'O'): 0.029286,
#  ('prev_word.lower=ambient', 'O'): 0.029583,
#  ('word.lower=our', 'O'): 0.147649,
#  ('word[-3:]=our', 'O'): 0.276131,
#  ('word[-2:]=ur', 'O'): 0.210443,
#  ('word[-2:]=ur', 'D'): -0.013613,
#  ('word.lower=urban', 'O'): 0.051549,
#  ('word[-3:]=ban', 'O'): 0.032827,
#  ('word[-3:]=ban', 'T'): 0.006617,
#  ('prev_word.lower=our', 'O'): 0.216329,
#  ('word.lower=area', 'O'): 0.13284,
#  ('word[-3:]=rea', 'O'): -0.072421,
#  ('word[-3:]=rea', 'T'): 0.200762,
#  ('word[-2:]=ea', 'O'): -0.860513,
#  ('word[-2:]=ea', 'D'): 0.803487,
#  ('word[-2:]=ea', 'T'): 0.057026,
#  ('prev_word.lower=urban', 'O'): 0.152179,
#  ('prev_word.lower=area', 'O'): 0.050144,
#  ('word.lower=subsequently', 'O'): 0.03371,
#  ('word[-3:]=tly', 'O'): 0.322367,
#  ('word.lower=obtained', 'O'): 0.081584,
#  ...}

# %%
X_test = [features_for_sentence(sentence) for sentence in test_sentences]
Y_test = [labels_for_sentence(labels) for labels in test_labels]

# %%
y_pred = crf.predict(X_test)

# %% [markdown]
# ### Task: 07: Calculate the F1 score

# %%
metrics.flat_f1_score(Y_test, y_pred, average='weighted')
# Out:
# 0.906724757630721

# %%
print(len(y_pred), len(test_sentences))
# Out:
# 1056 1056

# %% [markdown]
# ### Task-08: Get all predicted Treatment labels
# *and corresponding to each Disease label D in the test Dataaset*

# %%
overall_response = {}

for sent_index in range(len(y_pred)):
    current_disease = ''
    current_treatment = ''
    for label_index in range(len(y_pred[sent_index])):
        label = y_pred[sent_index][label_index]
        if label=='D':
            current_disease += test_sentences[sent_index].split()[label_index] + ' '
            #print('>D:', current_disease)
        elif label=='T':
            current_treatment += test_sentences[sent_index].split()[label_index] + ' '
            #print('>T:', current_treatment)

    current_disease = current_disease.strip()
    current_treatment = current_treatment.strip()

    if (len(current_disease) == 0 or len(current_treatment) == 0) :
        continue
    #print('>>D:', current_disease)
    #print('>>T:', current_treatment)
    #print('Disease Exists:', (current_disease in overall_response))
    #print('Disease:', overall_response[current_disease] )
    if current_disease in overall_response:
        overall_response[current_disease].append(current_treatment)
        #print(overall_response)
    else:
        overall_response[current_disease] = [current_treatment]
        #print(overall_response)

# %%
overall_response
# Out:
# {'hereditary retinoblastoma': ['radiotherapy'],
#  'myocardial infarction': ['warfarin with 80 mg aspirin , or 1 mg warfarin with 80 mg aspirin'],
#  'unstable angina or non-Q-wave myocardial infarction': ['roxithromycin'],
#  'primary pulmonary hypertension ( PPH )': ['fenfluramines'],
#  'foot infection': ['G-CSF treatment'],
#  "early Parkinson 's disease": ['Ropinirole monotherapy'],
#  'female stress urinary incontinence': ['surgical treatment'],
#  'stress urinary incontinence': ['therapy'],
#  'preeclampsia ( proteinuric hypertension )': ['intrauterine insemination with donor sperm versus intrauterine insemination'],
#  'intra-abdominal injury': ['senior surgery celiotomy'],
#  'cancer': ['organ transplantation and chemotherapy',
#   'oral drugs chemotherapy'],
#  'major pulmonary embolism': ['Thrombolytic treatment right-side hemodynamics'],
#  'malignant pleural mesothelioma': ['thoracotomy , radiotherapy , and chemotherapy'],
#  'tumor markers pulmonary symptoms': ['chemotherapy'],
#  'non-obstructive azoospermia': ['testicular fine needle aspiration ( TEFNA ) open biopsy and testicular sperm extraction ( TESE )'],
#  'colorectal cancer': ['Elective surgery', 'potential curative surgery'],
#  'gastrointestinal tumours': ['Elective surgery'],
#  "Parkinson 's disease": ['Microelectrode-guided posteroventral pallidotomy'],
#  'soft tissue sarcomas': ['Radiotherapy'],
#  "Eisenmenger 's syndrome": ['laparoscopic cholecystectomy'],
#  'advanced esophageal cancer': ['adjuvant chemoradiotherapy with CDDP'],
#  'breast cancer': ['Hormone replacement therapy',
#   'undergone subcutaneous mastectomy'],
#  'leukemia': ['Trisomy'],
#  'some malignant tumors such as non-small cell lung cancer': ['surgery'],
#  'inoperable advanced malignancies such as colorectal cancer': ['combination with leucovorin or cisplatin'],
#  'abdominal pain': ['thoracic paravertebral block ( tpvb )'],
#  'inflammatory skin diseases': ['topical corticosteroids'],
#  'unresectable stage iii nsclc': ['studies involving sequential chemotherapy'],
#  'nsclc nsclc ( stage iiib ) sclc': ['got surgical treatment'],
#  'nsclc': ['platinum-based chemotherapy', 'sequential chemotherapy'],
#  'locally advanced non-small-cell lung cancer ( la-nsclc )': ['chemotherapy and radiotherapy )'],
#  'radiation-induced myelopathy': ['heparin and enoxaparin'],
#  'limited stage small cell lung cancer': ['vip combination chemotherapy'],
#  'malignant pleural effusions from nsclc': ['systemic chemotherapy'],
#  'small-cell lung cancer': ['chemotherapy', 'combination chemotherapy'],
#  'intraluminal early-stage cancer': ['photodynamic therapy , nd-yag laser and electrocautery'],
#  'supraclavicular node metastases in nsclc': ['chemoradiotherapy'],
#  'non-small-cell-lung-cancer ( nsclc )': ['cisplatin and radiotherapy'],
#  'lung carcinoma': ['videothoracoscopic lobectomy or partial resection open thoracotomy'],
#  'stage 0 lung carcinoma': ['curative therapy'],
#  'single non-sclc melanoma ovarian carcinoma brain metastasis': ['surgical resection'],
#  'colorectal metastases': ['therapeutic vats metastasectomy'],
#  'advanced nsclc': ['combination chemotherapy of cisplatin , ifosfamide and irinotecan with rhg-csf support'],
#  'metastatic colorectal cancer': ['intravenous oxaliplatin'],
#  'platinum-pretreated ovarian cancer': ['oxaliplatin', 'oxaliplatin'],
#  "non-hodgkin 's lymphoma mesothelioma and non-small cell lung cancer": ['oxaliplatin'],
#  'non-small cell lung cancer advanced hormone refractory prostate cancer': ['combination with paclitaxel and carboplatin'],
#  'primary lung cancer adenocarcinoma squamous cell carcinoma': ['resection'],
#  'stage iii nsclc': ['chemotherapy administered before surgery'],
#  'small cell lung cancer': ['prophylactic cranial irradiation prolongs survival'],
#  'symptomatic metastases': ['radiotherapy'],
#  'main bronchus': ['radiotherapy first-line treatment'],
#  'primary cancer': ['adjuvant radiation therapy', 'Immunotherapy'],
#  'advanced non -- small-cell lung cancer': ['paclitaxel plus carboplatin ( pc ) vinorelbine plus cisplatin ( vc )'],
#  'two-year survivors among sclc extensive disease': ['platinum dose ( cisplatin plus carboplatin ) in combination chemotherapy combination therapy with carboplatin alone'],
#  'small cell lung cancer ( sclc ) untreated sclc': ['chemotherapy'],
#  'head and neck cancer acute and late grade > or =2 xerostomia': ['irradiation therapy intravenous amifostine'],
#  'disseminated malignant melanoma': ['leukocyte A recombinant interferon ( rIFN-alpha'],
#  'ventricular tachycardia': ['surgical therapy'],
#  'syringomyelia spinal adhesive arachnoiditis': ['Surgical management'],
#  'bronchiectasis': ['antibiotics and surgery', 'Current surgical therapy'],
#  'biliary dyskinesia': ['Cholecystectomy first-line therapy'],
#  'symptoms the common cold': ['pseudoephedrine plus acetaminophen'],
#  'acute nasopharyngitis ( ANP )': ['antibiotic treatment'],
#  'symptoms of a common cold': ['Macrolide antibiotics'],
#  'infection rhinovirus': ['clarithromycin'],
#  'infection': ['a combination of omeprazole , amoxicillin , and clarithromycin'],
#  'persistent asthma': ['Contemporary asthma management guidelines list inhaled corticosteroids'],
#  'asthma': ['Fluticasone propionate several inhaled corticosteroids'],
#  'chronic hepatitis C': ['Combination therapy with interferon-alpha ( IFN alpha ) plus Ribavirin'],
#  'hepatitis C viremia': ['combination therapy'],
#  'duodenogastric reflux': ['cholecystectomy'],
#  'severe hypoxemia': ['glucocorticoid pulse therapy'],
#  'primary sclerosing cholangitis': ['oral budesonide'],
#  'acute myocardial infarction': ['Thrombolytic therapy',
#   'thrombolytic treatment'],
#  'acute occlusion of the middle cerebral artery large embolus or high-grade stenosis': ['thrombolytic therapy'],
#  'benign prostatic hyperplasia': ['conservative pharmacological treatment'],
#  'autoimmune diseases': ['High-dose intravenous immunoglobulin ( hdIVIg )'],
#  'malignant melanoma': ['interferon alfa-2a'],
#  'advanced renal cell carcinoma': ['various interferon alpha preparations interferon alfa-N1 , interferon alfa-2a'],
#  'hairy cell leukemia infection': ['antileukemic therapy'],
#  "low-grade non-Hodgkin 's lymphoma": ['interferon alpha'],
#  'esophageal achalasia': ['botulinum toxin injection , pneumatic dilation , and laparoscopic myotomy'],
#  'proximal hypospadias': ['Tubularized incised plate hypospadias repair'],
#  'prostate cancer': ['radical prostatectomy and iodine 125 interstitial radiotherapy'],
#  'tumors': ['Immunotherapy'],
#  'mitomycin-resistant bladder cancer cell line': ['photodynamic therapy in combination with mitomycin C'],
#  'B16 melanoma': ['adenosine triphosphate and treatment with buthionine sulfoximine'],
#  'primary uveal melanoma': ['transpupillary thermotherapy'],
#  'advanced rectal cancer': ['Nerve-sparing surgery'],
#  'acute cerebral ischemia': ['Antiplatelet therapy'],
#  'renal cell carcinoma': ['Interferon treatment'],
#  'partial seizures': ['lamotrigine monotherapy'],
#  'myocardial angiogenesis': ['Gene therapy'],
#  'autoimmune hemolytic anemia': ['heparin'],
#  'multiple sclerosis': ['Interferon beta treatment',
#   'Intravenous immunoglobulin treatment'],
#  'acoustic neuroma': ['Stereotactic radiosurgery'],
#  'cerebral palsy': ['Hyperbaric oxygen therapy'],
#  'postvitrectomy diabetic vitreous hemorrhage': ['Peripheral retinal cryotherapy'],
#  'hepatitis B': ['vaccine'],
#  'temporomandibular joint arthropathy': ['arthroscopic treatment'],
#  'severe secondary peritonitis': ['Surgical management'],
#  'hepatic metastases from colorectal cancer': ['Hepatic arterial infusion of chemotherapy after resection'],
#  'chronic renal failure': ['Epoetin'],
#  'epithelial ovarian cancer': ['High-dose chemotherapy']}

# %% [markdown]
# ### Predict the treatment for the disease name: 'hereditary retinoblastoma'

# %%
overall_response['hereditary retinoblastoma']
# Out:
# ['radiotherapy']
